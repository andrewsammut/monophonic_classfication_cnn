# %%
from os import listdir
from os.path import isdir, join
import wave
import contextlib
import librosa
import soundfile as sf

# Dataset path and view possible targets
dataset_path = 'C:\\Users\\Greg\\ML\\Technical\\project\\git2\\monophonic_classfication_cnn\\features'
num_samples = 0
durations = []
sampdurations = []


for inst in listdir(dataset_path):
    inst2 = inst + "\\" + inst
    instrument = join(dataset_path, inst2)
    #print(instrument)
    for target in listdir(instrument):
        fname = join(instrument, target)
        #print(fname)
        with contextlib.closing(wave.open(fname,'r')) as f:
            frames = f.getnframes()
            rate = f.getframerate()
            duration = frames / float(rate)
            #print(rate)
            sampdurations.append(duration)
    maxd = max(sampdurations)
    mind = min(sampdurations)
    avg = sum(sampdurations) / len(sampdurations)
    print("max:", maxd)
    print("min:", mind)
    print("average:", avg)
    durations.extend(sampdurations)
    sampdurations.clear()
    print()
print("TOTAL Max / min values")
print("max max:", max(durations))
print("Min min:", min(durations))
sumd = sum(durations)
leng = len(durations)
print("average:", sumd / leng)
#for target in listdir(dataset_path):
#    print(len(listdir(join(dataset_path, target))))
#    num_samples += len(listdir(join(dataset_path, target)))
#print('Total samples:', num_samples)
# Out:
# max: 11.46607709750567
# min: 1.524625850340136
# average: 6.713010021212789
#
# max: 11.698979591836734
# min: 2.9489115646258504
# average: 6.840976103261816
#
# max: 14.010907029478458
# min: 1.4344897959183673
# average: 6.961111495445637
#
# max: 9.50875283446712
# min: 3.3766213151927436
# average: 6.931843711843712
#
# max: 12.261995464852607
# min: 1.4124036281179138
# average: 6.576105990783412
#
# max: 11.428979591836734
# min: 3.1309750566893424
# average: 6.848226059654631
#
# max: 8.82281179138322
# min: 1.5946031746031746
# average: 6.077649969078541
#
# max: 10.202426303854875
# min: 1.5580272108843538
# average: 6.395924950625411
#
# max: 8.977596371882086
# min: 1.419342403628118
# average: 5.996943200044244
#
# max: 11.60687074829932
# min: 1.5843764172335602
# average: 6.515938848657742
#
# max: 8.364716553287982
# min: 1.4719501133786848
# average: 6.0503074829931975
#
# max: 9.98702947845805
# min: 1.57578231292517
# average: 6.604753532182105
#
# max: 11.257482993197279
# min: 1.315170068027211
# average: 6.672763718820863
#
# max: 10.598004535147393
# min: 1.3931519274376418
# average: 6.7955282112845135
#
# max: 11.918888888888889
# min: 1.4456009070294784
# average: 6.523943355119825
#
# max: 10.281541950113379
# min: 1.662607709750567
# average: 6.668026867312581
#
# max: 16.235351473922904
# min: 1.4464625850340136
# average: 6.253352084423513
#
# max: 11.738775510204082
# min: 3.5596371882086166
# average: 6.789627195510972
#
# max: 11.796167800453516
# min: 1.4164172335600906
# average: 6.113423110740894
#
# max: 10.911179138321996
# min: 1.3251020408163265
# average: 6.636238967381824
#
# max: 15.728616780045352
# min: 1.4463718820861677
# average: 6.8662807948037985
#
# max: 13.113968253968254
# min: 2.982312925170068
# average: 7.03108997271225
#
# TOTAL Max / min values
# max max: 16.235351473922904
# Min min: 1.315170068027211
# average: 6.613918261054425

# %%
samplepath = 'C:\\Users\\Greg\\ML\\Technical\\project\\git2\\monophonic_classfication_cnn\\features'
outputpath = 'C:\\Users\\Greg\\ML\\Technical\\project\\git2\\monophonic_classfication_cnn\\padded'
durationSeconds = 1

#for samples in listdir(samplepath):
 #   sample = join(samplepath, samples)
#    data, sr = librosa.load(sample, sr=None, mono=False)
#    trimmed = librosa.util.fix_length(data, int(sr * durationSeconds))
#    pad = "pad" + samples
#    padding = join(outputpath, pad)
#    sf.write(padding, trimmed, sr)
  #  librosa.output.write_wav(padding, trimmed, sr)for samples in listdir(samplepath):

for inst in listdir(samplepath):
    inst2 = inst + "\\" + inst
    instrument = join(samplepath, inst2)
    padinst = join(outputpath, inst)
    for target in listdir(instrument):
        sound = join(instrument, target)
        #padsamp = join(padsounds, samps)
        data, sr = librosa.load(sound, sr=None, mono=False)
        trimmed = librosa.util.fix_length(data, int(sr * durationSeconds))
        pad = "pad" + target
        padding = join(padinst, pad)
        sf.write(padding, trimmed, sr)
# Out:
# 0.9.1
# C:\Users\Greg\AppData\Local\Temp\ipykernel_17896\2251152520.py:23: FutureWarning: Pass size=44100 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   trimmed = librosa.util.fix_length(data, int(sr * durationSeconds))
